# %% [markdown]
# # Mapping Yelp Search Results - Part 1

# %% [markdown]
# - 04/26/22

# %% [markdown]
# ## Obective

# %% [markdown]
# - For this CodeAlong, we will be working with the Yelp API.
# - You will use the the Yelp API to search your home town for a cuisine type of your choice.
# - Next class, we will then use Plotly Express to create a map with the Mapbox API to visualize the results.

# %% [markdown]
# ## Tools You Will Use
# - Part 1:
#     - Yelp API:
#         - Getting Started:
#             - https://www.yelp.com/developers/documentation/v3/get_started
#
#     - `YelpAPI` python package
#         -  "YelpAPI": https://github.com/gfairchild/yelpapi
# - Part 2:
#
#     - Plotly Express: https://plotly.com/python/getting-started/
#         - With Mapbox API: https://www.mapbox.com/
#         - `px.scatter_mapbox` [Documentation](https://plotly.com/python/scattermapbox/):

# %% [markdown]
# ### Applying Code From
# - Efficient API Calls Lesson Link: https://login.codingdojo.com/m/376/12529/88078

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# ## 1. Registering for Required APIs

# %% [markdown]
# - Yelp: https://www.yelp.com/developers/documentation/v3/get_started

# %% [markdown]
# > Check the official API documentation to know what arguments we can search for: https://www.yelp.com/developers/documentation/v3/business_search

# %% [markdown]
# ### Load Credentials and Create Yelp API Object

# %%
# Load API Credentials
with open('/Users/chas/.secret/yelp_api.json', 'r') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelpapi = YelpAPI(login['api-key'], timeout_s=5)
yelpapi

# %% [markdown]
# ### Define Search Terms and File Paths

# %%
# set our API call parameters and filename before the first call
LOCATION = 'Reading, PA, 19601'
TERM = 'Chinese'

# %%
## Specify folder for saving data
FOLDER = 'Data/'
os.makedirs(FOLDER, exist_ok=True)

# %%
LOCATION.split(',')[0]
# Out:
# 'Reading'

# %%
# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = f"{FOLDER}{TERM}_{LOCATION.split(',')[0]}.json"
JSON_FILE
# Out:
# 'Data/Chinese_Reading.json'

# %% [markdown]
# ### Check if Json File exists and Create it if it doesn't

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:    
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    #saving empty file
    with open(JSON_FILE, 'w') as f:
        json.dump([], f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Chinese_Reading.json already exists.

# %% [markdown]
# ### Load JSON FIle and account for previous results

# %%
## Load previous results and use len of results for offset
with open (JSON_FILE, 'r') as f:
    previous_results = json.load(f)
## set offset based on previous results
n_results = len(previous_results)
print(f"-{n_results} previous results found")
# Out:
# -0 previous results found

# %% [markdown]
# ### Make the first API call to get the first page of data

# %% [markdown]
# - We will use this first result to check:
#     - how many total results there are?
#     - Where is the actual data we want to save?
#     - how many results do we get at a time?

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelpapi.search_query(location = LOCATION, 
                              term = TERM)
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
## How many results total?
results['total']
# Out:
# 36

# %% [markdown]
# - Where is the actual data we want to save?

# %%
type(results['businesses'])
# Out:
# list

# %%
results['businesses']
# Out:
# [{'id': 'bGoiESr-CoxvhLy3wE_EMA',
#   'alias': 'great-wall-chinese-restaurant-west-reading-2',
#   'name': 'Great Wall Chinese Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OVeudbsNLduHBici992cHA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/great-wall-chinese-restaurant-west-reading-2?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 26,
#   'categories': [{'alias': 'cantonese', 'title': 'Cantonese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.33542, 'longitude': -75.94889},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '532 Penn Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'West Reading',
#    'zip_code': '19611',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['532 Penn Ave', 'West Reading, PA 19611']},
#   'phone': '+16106858585',
#   'display_phone': '(610) 685-8585',
#   'distance': 2447.801816204594},
#  {'id': 'CVnvnYpDu3DuFBEnTiN5_g',
#   'alias': 'wongs-chinese-restaurant-reading',
#   'name': "Wong's Chinese Restaurant",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bYG6bWvdowFqU9i1LMHDgA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wongs-chinese-restaurant-reading?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 14,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.365425, 'longitude': -75.919975},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '835-5 Hiesters Ln',
#    'address2': None,
#    'address3': '',
#    'city': 'Reading',
#    'zip_code': '19605',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['835-5 Hiesters Ln', 'Reading, PA 19605']},
#   'phone': '+16109291999',
#   'display_phone': '(610) 929-1999',
#   'distance': 2062.2331792968603},
#  {'id': 'x4aZiu4up011rNrkS-F_aQ',
#   'alias': 'fortune-cafe-wyomissing-2',
#   'name': 'Fortune Cafe',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7rInx1N0B9qEa14QbYpxzA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fortune-cafe-wyomissing-2?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 18,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.3423, 'longitude': -75.9809},
#   'transactions': ['delivery'],
#   'location': {'address1': '1177 Berkshire Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Wyomissing',
#    'zip_code': '19610',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1177 Berkshire Blvd', 'Wyomissing, PA 19610']},
#   'phone': '+16103965329',
#   'display_phone': '(610) 396-5329',
#   'distance': 3721.7894923937947},
#  {'id': '-kVxn8rVRPkcbRChaMQF9A',
#   'alias': 'wonderful-chinese-restaurant-reading',
#   'name': 'Wonderful Chinese Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/q5t1vH10JJDlb4XBxx03Cw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wonderful-chinese-restaurant-reading?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 19,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.3262672424316,
#    'longitude': -76.0293579101562},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '4301 Penn Ave',
#    'address2': None,
#    'address3': None,
#    'city': 'Reading',
#    'zip_code': '19608',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['4301 Penn Ave', 'Reading, PA 19608']},
#   'phone': '+16106788388',
#   'display_phone': '(610) 678-8388',
#   'distance': 8194.366784164775},
#  {'id': '0AXHF41K7QZcfWlvCJYXzw',
#   'alias': 'no-1-chinese-restaurant-reading-4',
#   'name': 'No.1 Chinese Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WQv6hO_NarXYTeel1rld2w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/no-1-chinese-restaurant-reading-4?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 30,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.2987075, 'longitude': -75.9473523},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '160 Kenhorst Plz',
#    'address2': '',
#    'address3': '',
#    'city': 'Reading',
#    'zip_code': '19607',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['160 Kenhorst Plz', 'Reading, PA 19607']},
#   'phone': '+16107750875',
#   'display_phone': '(610) 775-0875',
#   'distance': 6377.472186293713},
#  {'id': 'UDjJEM5xlmmxseGERcihNw',
#   'alias': 'chans-chinese-restaurant-reading',
#   'name': "Chan's Chinese Restaurant",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UIzJqI14UXVBhJb045H19A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chans-chinese-restaurant-reading?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 6,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.3321, 'longitude': -75.92966},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '201 S 4th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Reading',
#    'zip_code': '19602',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['201 S 4th St', 'Reading, PA 19602']},
#   'phone': '+16103721200',
#   'display_phone': '(610) 372-1200',
#   'distance': 2911.8772383960345},
#  {'id': 'Dx1Ay1Vtk8eCZCGRHHQoyw',
#   'alias': 'mikura-reading',
#   'name': 'Mikura',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r5gkRdPDsAgxD2_OMwSWXw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mikura-reading?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 106,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'thai', 'title': 'Thai'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.3464, 'longitude': -75.95944},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '840 N Park Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Reading',
#    'zip_code': '19610',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['840 N Park Rd', 'Reading, PA 19610']},
#   'phone': '+16103735851',
#   'display_phone': '(610) 373-5851',
#   'distance': 1910.1642284069765},
#  {'id': 'qAT7gKm5Ndi0e0prictoOA',
#   'alias': 'china-wok-reading',
#   'name': 'China Wok',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dIhrAStmrPc6aRnBFpioHA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-wok-reading?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 15,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.38523, 'longitude': -75.92713},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '3401 N 5th Street Hwy',
#    'address2': None,
#    'address3': None,
#    'city': 'Reading',
#    'zip_code': '19605',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['3401 N 5th Street Hwy', 'Reading, PA 19605']},
#   'phone': '+16109298383',
#   'display_phone': '(610) 929-8383',
#   'distance': 3391.1389936499463},
#  {'id': 'nWSYTpcPOTmoWAw-_6vpvA',
#   'alias': 'tokyo-hibachi-and-bar-wyomissing',
#   'name': 'Tokyo Hibachi & Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6BXRDefNkgt8AKiGl2aumw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tokyo-hibachi-and-bar-wyomissing?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 128,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.34523, 'longitude': -75.96808},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '960 Woodland Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Wyomissing',
#    'zip_code': '19610',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['960 Woodland Rd', 'Wyomissing, PA 19610']},
#   'phone': '+16106852888',
#   'display_phone': '(610) 685-2888',
#   'distance': 2628.777696388009},
#  {'id': 'Qwd8unlaye8Oov7qPmU3uA',
#   'alias': 'china-fun-restaurant-reading',
#   'name': 'China Fun Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kXEyFdOL3QP_ID67Dkfmgg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-fun-restaurant-reading?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 13,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.3867987, 'longitude': -75.9345104},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '3611 Pottsville Pike',
#    'address2': '',
#    'address3': '',
#    'city': 'Reading',
#    'zip_code': '19605',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['3611 Pottsville Pike', 'Reading, PA 19605']},
#   'phone': '+16109390775',
#   'display_phone': '(610) 939-0775',
#   'distance': 3417.6931428203357},
#  {'id': 'Uvf6IJ3rtIoUf17tQAgdeg',
#   'alias': 'great-china-reading',
#   'name': 'Great China',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OryjzCpyYzUsNdO5arY24Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/great-china-reading?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 20,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.3160268, 'longitude': -76.0009589},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '2675 Shillington Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Reading',
#    'zip_code': '19608',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['2675 Shillington Rd', 'Reading, PA 19608']},
#   'phone': '+16106789222',
#   'display_phone': '(610) 678-9222',
#   'distance': 6755.290102838181},
#  {'id': 'l1n5ERIIVl8E4ynngU1Xsg',
#   'alias': 'zhuangs-garden-west-lawn-3',
#   'name': "Zhuang's Garden",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Pt4b5vDD7p1pzo3Kw7zCQw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zhuangs-garden-west-lawn-3?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 87,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.325632, 'longitude': -76.002515},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2834 Penn Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'West Lawn',
#    'zip_code': '19609',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['2834 Penn Ave', 'West Lawn, PA 19609']},
#   'phone': '+16106705650',
#   'display_phone': '(610) 670-5650',
#   'distance': 6231.960797223748},
#  {'id': 'LnoNsqdAvecaKvvrXqk1KQ',
#   'alias': 'regal-buffet-reading',
#   'name': 'Regal Buffet',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PLyChnZMO0tUqTwDIhOHSw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/regal-buffet-reading?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 117,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'buffets', 'title': 'Buffets'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.3826331413064,
#    'longitude': -75.9286554713423},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '3252 N 5th St Hwy',
#    'address2': '',
#    'address3': None,
#    'city': 'Reading',
#    'zip_code': '19605',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['3252 N 5th St Hwy', 'Reading, PA 19605']},
#   'phone': '+16109211998',
#   'display_phone': '(610) 921-1998',
#   'distance': 3071.651126806257},
#  {'id': 'naq2UQIZYeZAr9mKLH0Clg',
#   'alias': 'new-happy-garden-temple',
#   'name': 'New Happy Garden',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/s0Sugy4wjHVa12oUAy86QQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/new-happy-garden-temple?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 12,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 40.4013, 'longitude': -75.92704},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '4447 N 5th St Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Temple',
#    'zip_code': '19560',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['4447 N 5th St Hwy', 'Temple, PA 19560']},
#   'phone': '+16109218559',
#   'display_phone': '(610) 921-8559',
#   'distance': 5093.983112414516},
#  {'id': '4NeP-dg4R3iFkT3SGTybMA',
#   'alias': 'thaiwat-reading',
#   'name': 'Thaiwat',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/B_iRo2o2sYmcZgwmYW9d-A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thaiwat-reading?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 77,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.3418259, 'longitude': -75.9794712},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1145 Berkshire Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Reading',
#    'zip_code': '19610',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1145 Berkshire Blvd', 'Reading, PA 19610']},
#   'phone': '+16108989191',
#   'display_phone': '(610) 898-9191',
#   'distance': 3636.6686926235225},
#  {'id': '66K0BTuSibMwfTGHs-5cVg',
#   'alias': 'chen-vegetarian-house-west-reading',
#   'name': 'Chen Vegetarian House',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FeXYzXy_PTVVRyt7nzFXuw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chen-vegetarian-house-west-reading?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 102,
#   'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#    {'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.336243, 'longitude': -75.9521479},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '709 Penn Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'West Reading',
#    'zip_code': '19611',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['709 Penn Ave', 'West Reading, PA 19611']},
#   'phone': '+16103742288',
#   'display_phone': '(610) 374-2288',
#   'distance': 2457.9884096268693},
#  {'id': 'oDMp1VC5sz7hSOe6E5WQBQ',
#   'alias': 'spoonful-thai-bistro-west-reading',
#   'name': 'Spoonful Thai Bistro',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AcT7qEPgrif0roCU1jjpxw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/spoonful-thai-bistro-west-reading?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 11,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.33614, 'longitude': -75.95036},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '615 Penn Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'West Reading',
#    'zip_code': '19611',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['615 Penn Ave', 'West Reading, PA 19611']},
#   'phone': '+14848782941',
#   'display_phone': '(484) 878-2941',
#   'distance': 2416.2875660182526},
#  {'id': 'rXWol0qtMhr8jQy8wwMT9A',
#   'alias': 'chengdu-taste-reading',
#   'name': 'Chengdu Taste',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SQqiRPb3J4bYrrfo1CtMsw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chengdu-taste-reading?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 1,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.36461, 'longitude': -75.91347},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '1140 Rockland St',
#    'address2': '',
#    'address3': None,
#    'city': 'Reading',
#    'zip_code': '19604',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1140 Rockland St', 'Reading, PA 19604']},
#   'phone': '+16107507017',
#   'display_phone': '(610) 750-7017',
#   'distance': 2508.7572486420513},
#  {'id': 'EMM_UNHD_hmkYLzpWO3dhg',
#   'alias': 'china-king-restaurant-wyomissing',
#   'name': 'China King Restaurant',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-king-restaurant-wyomissing?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 1,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.3464, 'longitude': -75.95944},
#   'transactions': ['delivery'],
#   'location': {'address1': '840 N Park Rd',
#    'address2': 'Ste 7',
#    'address3': None,
#    'city': 'Wyomissing',
#    'zip_code': '19610',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['840 N Park Rd', 'Ste 7', 'Wyomissing, PA 19610']},
#   'phone': '+16103738805',
#   'display_phone': '(610) 373-8805',
#   'distance': 1910.1642284069765},
#  {'id': 'C-Ls4LyvJyf1hcTqmoVrdw',
#   'alias': 'china-house-reading',
#   'name': 'China House',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-house-reading?adjust_creative=pmEh1CnvTrbj1V5gF4_06w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pmEh1CnvTrbj1V5gF4_06w',
#   'review_count': 3,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 40.381893, 'longitude': -75.925508},
#   'transactions': ['delivery'],
#   'location': {'address1': '3215 N 5th Street Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Reading',
#    'zip_code': '19605',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['3215 N 5th Street Hwy', 'Reading, PA 19605']},
#   'phone': '+16109399838',
#   'display_phone': '(610) 939-9838',
#   'distance': 3099.865460152619}]

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %% [markdown]
# - Calculate how many pages of results needed to cover the total_results

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil(results['total']/results_per_page)
n_pages
# Out:
# 2

# %%
for i in tqdm_notebook( range(0,n_pages+1)):
    ## The block of code we want to TRY to run
        try:
            time.sleep(.2)
            ## Read in results in progress file and check the length
            with open (JSON_FILE, 'r') as f:
                previous_results = json.load(f)
            ## set offset based on previous results
            n_results = len(previous_results)

             ## use n_results as the OFFSET 
            results = yelpapi.search_query(location = LOCATION, 
                                       term = TERM,
                                       offset = n_results+1)
            
            ## append new results and save to file
            previous_results.extend(results['businesses'])

            with open(JSON_FILE, 'w') as f:
                json.dump(previous_results, f)
    ## What to do if we get an error/exception.
        except Exception as e:
            print(e)
            break
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ## Open the Final JSON File with Pandas

# %%
df = pd.read_json(JSON_FILE)
df
# Out:
#                         id                                     alias  \
# 0   CVnvnYpDu3DuFBEnTiN5_g          wongs-chinese-restaurant-reading
# 1   x4aZiu4up011rNrkS-F_aQ                 fortune-cafe-wyomissing-2
# 2   -kVxn8rVRPkcbRChaMQF9A      wonderful-chinese-restaurant-reading
# 3   0AXHF41K7QZcfWlvCJYXzw         no-1-chinese-restaurant-reading-4
# 4   UDjJEM5xlmmxseGERcihNw          chans-chinese-restaurant-reading
# 5   Dx1Ay1Vtk8eCZCGRHHQoyw                            mikura-reading
# 6   qAT7gKm5Ndi0e0prictoOA                         china-wok-reading
# 7   nWSYTpcPOTmoWAw-_6vpvA          tokyo-hibachi-and-bar-wyomissing
# 8   Qwd8unlaye8Oov7qPmU3uA              china-fun-restaurant-reading
# 9   Uvf6IJ3rtIoUf17tQAgdeg                       great-china-reading
# 10  l1n5ERIIVl8E4ynngU1Xsg                zhuangs-garden-west-lawn-3
# 11  LnoNsqdAvecaKvvrXqk1KQ                      regal-buffet-reading
# 12  naq2UQIZYeZAr9mKLH0Clg                   new-happy-garden-temple
# 13  4NeP-dg4R3iFkT3SGTybMA                           thaiwat-reading
# 14  66K0BTuSibMwfTGHs-5cVg        chen-vegetarian-house-west-reading
# 15  oDMp1VC5sz7hSOe6E5WQBQ         spoonful-thai-bistro-west-reading
# 16  rXWol0qtMhr8jQy8wwMT9A                     chengdu-taste-reading
# 17  EMM_UNHD_hmkYLzpWO3dhg          china-king-restaurant-wyomissing
[{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.5
# 1          [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
# 2   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.5
# 3          [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
# 4          [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
# 5   [{'alias': 'asianfusion', 'title': 'Asian Fusi...     3.5
# 6          [{'alias': 'chinese', 'title': 'Chinese'}]     3.5
# 7   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     3.5
# 8          [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 9          [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 10  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     3.5
# 11  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     3.5
# 12         [{'alias': 'chinese', 'title': 'Chinese'}]     2.0
# 13               [{'alias': 'thai', 'title': 'Thai'}]     4.0
# 14  [{'alias': 'vegetarian', 'title': 'Vegetarian'...     4.5
# 15               [{'alias': 'thai', 'title': 'Thai'}]     4.0
# 16  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     3.0
# 17         [{'alias': 'chinese', 'title': 'Chinese'}]     3.0
# 18         [{'alias': 'chinese', 'title': 'Chinese'}]     2.5
# 19         [{'alias': 'chinese', 'title': 'Chinese'}]     2.0
# 20  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     2.5
# 21  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     3.5
# 22         [{'alias': 'chinese', 'title': 'Chinese'}]     3.5
# 23         [{'alias': 'chinese', 'title': 'Chinese'}]     2.5
# 24         [{'alias': 'chinese', 'title': 'Chinese'}]     2.5
# 25  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     2.0
# 26  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     2.5
# 27         [{'alias': 'chinese', 'title': 'Chinese'}]     2.5
# 28         [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 29  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     2.0
# 30         [{'alias': 'chinese', 'title': 'Chinese'}]     2.0
# 31         [{'alias': 'chinese', 'title': 'Chinese'}]     3.5
# 32         [{'alias': 'chinese', 'title': 'Chinese'}]     2.5
# 33         [{'alias': 'chinese', 'title': 'Chinese'}]     2.5
# 34  [{'alias': 'soup', 'title': 'Soup'}, {'alias':...     4.0
#
#                                           coordinates        transactions  \
# 0    {'latitude': 40.365425, 'longitude': -75.919975}          [delivery]
# 1        {'latitude': 40.3423, 'longitude': -75.9809}          [delivery]
# 2   {'latitude': 40.3262672424316, 'longitude': -7...          [delivery]
# 3   {'latitude': 40.2987075, 'longitude': -75.9473...          [delivery]
# 4       {'latitude': 40.3321, 'longitude': -75.92966}          [delivery]
# 5       {'latitude': 40.3464, 'longitude': -75.95944}  [pickup, delivery]
# 6      {'latitude': 40.38523, 'longitude': -75.92713}          [delivery]
# 7      {'latitude': 40.34523, 'longitude': -75.96808}  [pickup, delivery]
# 8   {'latitude': 40.3867987, 'longitude': -75.9345...          [delivery]
# 9   {'latitude': 40.3160268, 'longitude': -76.0009...          [delivery]
# 10   {'latitude': 40.325632, 'longitude': -76.002515}  [pickup, delivery]
# 11  {'latitude': 40.3826331413064, 'longitude': -7...          [delivery]
# 12      {'latitude': 40.4013, 'longitude': -75.92704}          [delivery]
# 13  {'latitude': 40.3418259, 'longitude': -75.9794...  [pickup, delivery]
# 14  {'latitude': 40.336243, 'longitude': -75.9521479}          [delivery]
# 15     {'latitude': 40.33614, 'longitude': -75.95036}  [pickup, delivery]
# 16     {'latitude': 40.36461, 'longitude': -75.91347}  [pickup, delivery]
# 17      {'latitude': 40.3464, 'longitude': -75.95944}          [delivery]
# 18   {'latitude': 40.381893, 'longitude': -75.925508}          [delivery]
# 19   {'latitude': 40.345343, 'longitude': -75.921025}          [delivery]
# 20   {'latitude': 40.312462, 'longitude': -75.866755}  [delivery, pickup]
# 21  {'latitude': 40.377121, 'longitude': -75.9305115}          [delivery]
# 22  {'latitude': 40.3413868, 'longitude': -75.9703...                  []
# 23      {'latitude': 40.37452, 'longitude': -75.9186}          [delivery]
# 24  {'latitude': 40.295742485173406, 'longitude': ...          [delivery]
# 25     {'latitude': 40.33498, 'longitude': -75.92036}          [delivery]
# 26      {'latitude': 40.30527, 'longitude': -75.9751}  [delivery, pickup]
# 27  {'latitude': 40.3892135620117, 'longitude': -7...          [delivery]
# 28   {'latitude': 40.335087, 'longitude': -75.930725}          [delivery]
# 29   {'latitude': 40.331886, 'longitude': -75.888855}                  []
# 30  {'latitude': 40.3443162692069, 'longitude': -7...  [delivery, pickup]
# 31  {'latitude': 40.3248063465625, 'longitude': -7...          [delivery]
# 32  {'latitude': 40.3418960571289, 'longitude': -7...          [delivery]
# 33  {'latitude': 40.3287093199229, 'longitude': -7...          [delivery]
# 34  {'latitude': 40.3498605, 'longitude': -75.9649...  [delivery, pickup]
#
#    price                                           location        phone  \
# 0      $  {'address1': '835-5 Hiesters Ln', 'address2': ...  16109291999
# 1    NaN  {'address1': '1177 Berkshire Blvd', 'address2'...  16103965329
# 2      $  {'address1': '4301 Penn Ave', 'address2': None...  16106788388
# 3      $  {'address1': '160 Kenhorst Plz', 'address2': '...  16107750875
# 4     $$  {'address1': '201 S 4th St', 'address2': '', '...  16103721200
# 5     $$  {'address1': '840 N Park Rd', 'address2': '', ...  16103735851
# 6      $  {'address1': '3401 N 5th Street Hwy', 'address...  16109298383
# 7     $$  {'address1': '960 Woodland Rd', 'address2': ''...  16106852888
# 8     $$  {'address1': '3611 Pottsville Pike', 'address2...  16109390775
# 9      $  {'address1': '2675 Shillington Rd', 'address2'...  16106789222
# 10    $$  {'address1': '2834 Penn Ave', 'address2': '', ...  16106705650
# 11    $$  {'address1': '3252 N 5th St Hwy', 'address2': ...  16109211998
# 12     $  {'address1': '4447 N 5th St Hwy', 'address2': ...  16109218559
# 13    $$  {'address1': '1145 Berkshire Blvd', 'address2'...  16108989191
# 14    $$  {'address1': '709 Penn Ave', 'address2': '', '...  16103742288
# 15   NaN  {'address1': '615 Penn Ave', 'address2': None,...  14848782941
# 16   NaN  {'address1': '1140 Rockland St', 'address2': '...  16107507017
# 17   NaN  {'address1': '840 N Park Rd', 'address2': 'Ste...  16103738805
# 18   NaN  {'address1': '3215 N 5th Street Hwy', 'address...  16109399838
# 19   NaN  {'address1': '632 Greenwich St', 'address2': '...  16103724471
# 20    $$  {'address1': '4203 Perkiomen Ave', 'address2':...  16107799754
# 21    $$  {'address1': '502 Eisenbrown St', 'address2': ...  16109296993
# 22     $  {'address1': '1665 State Hill Rd', 'address2':...  16103718865
# 23   NaN  {'address1': '2605 Kutztown Rd', 'address2': N...  16107505593
# 24     $  {'address1': '5506 Perkiomen Ave', 'address2':...  16104040008
# 25   NaN  {'address1': '850 Penn St', 'address2': '', 'a...  16103718680
# 26    $$  {'address1': '450 W Lancaster Ave', 'address2'...  16107968979
# 27   NaN  {'address1': '2727 Bernville Rd', 'address2': ...  16109168872
# 28   NaN  {'address1': '334 Penn St', 'address2': '', 'a...  16103768088
# 29     $  {'address1': '267 Carsonia Ave', 'address2': '...  16109275666
# 30   NaN  {'address1': '2104 Van Reed Rd', 'address2': '...  19179155218
# 31     $  {'address1': '3564 Penn Ave', 'address2': '', ...  16106701556
# 32     $  {'address1': '101 W Buttonwood St', 'address2'...  16104787303
# 33     $  {'address1': '2900 Saint Lawrence Ave', 'addre...  16107795522
# 34     $  {'address1': '760 Woodland Rd', 'address2': ''...  16103726717
#
#      display_phone      distance
# 0   (610) 929-1999   2062.233179
# 1   (610) 396-5329   3721.789492
# 2   (610) 678-8388   8194.366784
# 3   (610) 775-0875   6377.472186
# 4   (610) 372-1200   2911.877238
# 5   (610) 373-5851   1910.164228
# 6   (610) 929-8383   3391.138994
# 7   (610) 685-2888   2628.777696
# 8   (610) 939-0775   3417.693143
# 9   (610) 678-9222   6755.290103
# 10  (610) 670-5650   6231.960797
# 11  (610) 921-1998   3071.651127
# 12  (610) 921-8559   5093.983112
# 13  (610) 898-9191   3636.668693
# 14  (610) 374-2288   2457.988410
# 15  (484) 878-2941   2416.287566
# 16  (610) 750-7017   2508.757249
# 17  (610) 373-8805   1910.164228
# 18  (610) 939-9838   3099.865460
# 19  (610) 372-4471   2133.117210
# 20  (610) 779-9754   8008.483210
# 21  (610) 929-6993   2457.592911
# 22  (610) 371-8865   2997.506199
# 23  (610) 750-5593   2754.646586
# 24  (610) 404-0008  10639.939172
# 25  (610) 371-8680   2992.855330
# 26  (610) 796-8979   6404.631856
# 27  (610) 916-8872   5644.070125
# 28  (610) 376-8088   2568.554325
# 29  (610) 927-5666   5231.926768
# 30  (917) 915-5218   5331.399201
# 31  (610) 670-1556   6991.468472
# 32  (610) 478-7303   1722.734076
# 33  (610) 779-5522   6186.071958
# 34  (610) 372-6717   2144.545444

# %%
#check for duplicates
df.duplicated(subset='id').sum()
# Out:
# 0

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Chinese_Reading.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression='gzip', index=False)

# %% [markdown]
# ## Bonus: compare filesize with os module's `os.path.getsize`

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize(JSON_FILE.replace('.json','.csv.gz'))

print(f'JSON FILE: {size_json:,} Bytes')
print(f'CSV.GZ FILE: {size_csv_gz:,} Bytes')

print(f'the csv.gz is {size_json/size_csv_gz} times smaller!')
# Out:
# JSON FILE: 32,808 Bytes
# CSV.GZ FILE: 5,180 Bytes
# the csv.gz is 6.333590733590734 times smaller!

# %% [markdown]
# ## Next Class: Processing the Results and Mapping
